# %%
# !pip install numpy
# !pip install pandas
# !pip install sklearn
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/61.0 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 651.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.2/15.5 MB 5.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/15.5 MB 5.5 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/15.5 MB 5.7 MB/s eta 0:00:03
#    -- ------------------------------------- 1.1/15.5 MB 5.6 MB/s eta 0:00:03
#    --- ------------------------------------ 1.3/15.5 MB 6.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.6/15.5 MB 5.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.8/15.5 MB 5.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.1/15.5 MB 5.7 MB/s eta 0:00:03
# ...

# %%
import pandas

# %%
import numpy

# %%
import matplotlib

# %%
import sklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import sklearn
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      -------------------------------------- 60.6/60.6 kB 811.9 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.9 MB 5.1 MB/s eta 0:00:03
#    - -------------------------------------- 0.5/10.9 MB 5.1 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/10.9 MB 7.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.5/10.9 MB 8.9 MB/s eta 0:00:02
#    ------- -------------------------------- 1.9/10.9 MB 8.8 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/10.9 MB 8.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.8/10.9 MB 9.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.2/10.9 MB 8.9 MB/s eta 0:00:01
# ...

# %%
import scikit-learn
# Out:
#   Cell In[7], line 1
#     import scikit-learn
#                  ^
# SyntaxError: invalid syntax

# %%
import scikit-learn
# Out:
#   Cell In[8], line 1
#     import scikit-learn
#                  ^
# SyntaxError: invalid syntax

# %%
import sklearn
